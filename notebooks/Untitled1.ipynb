# %%
import os
import sys
sys.executable
import _sqlite3
from db import db_path
import pandas as pd
print(db_path)
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
# Out:
# /home/jakub/DataNinja/data/database/

# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import _sqlite3
conn = _sqlite3.connect(db_path + '2016_11.db')

start = time.time()
df = pd.read_sql_query("Select user_id from ads", conn)
all_users = df['user_id'].value_counts()
prob = all_users[:120].to_dict()
all_users = all_users.to_dict()
indexes=np.arange(len(prob))
plt.figure(figsize=(22,7))

plt.bar(indexes,prob.values())
plt.xticks(indexes,prob.keys(),rotation=90)
plt.show()

# %%
user = 
def assign_user_ads(user_id):
    ad_count = 1000000
    return all_users[user_id]/ad_count
print(assign_user_ads(user))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-a6519fbb3a19> in <module>()
#       3     ad_count = 1000000
#       4     return all_users[user_id]/ad_count
# ----> 5 print(assign_user_ads(user))
#
# <ipython-input-11-a6519fbb3a19> in assign_user_ads(user_id)
#       2 def assign_user_ads(user_id):
#       3     ad_count = 1000000
# ----> 4     return all_users[user_id]/ad_count
#       5 print(assign_user_ads(user))
#
# KeyError: 1640171958

# %%
print(len(all_users))
# Out:
# 414800
